# %%
print("merhaba")

# %%
import sys # import phyton proglamlama dilinde yazılıma kütüphane eklemeye yarar
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/YZIGU')

# %%
import pandas as pd
#Alinin ders ve not bilgileri
data= {'Ders':['Algoritma',' BilgisayarProglamlama', ' Elektronik-2', 'AviyonikSistemler'],
      'Not':[95,100,65,90]}

df = pd.DataFrame(data)

#En yüksek notu bul
en_yuksek_not = df['Not'].max()
print("en yüksek not:", en_yuksek_not)
#Ortalama notu hesapla
ortalama_not=df['Not'].mean()
print("Ortalama not:", ortalama_not)
en_dusuk_not=df['Not'].min()
print("En düşük not:", en_dusuk_not)
print(df.describe())
# Out:
# en yüksek not: 100
# Ortalama not: 87.5
# En düşük not: 65
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %%
import numpy as np
#rastgele tanımlanan değerler - sıralaması olmayan
dizi= np.array([1,-55,9,-23,13,-21,23,37,29,-6])
#Dizinin ortalama sonuc
ortalama=np.mean(dizi)
print("Ortalama:",ortalama)
#dizinin standart sapma
std_sapma=np.std(dizi)
print("standart sapma:", std_sapma)
#dizinin mutlağını al
mutlak_veriler=np.abs(dizi)
print("logaritmik veriler:",mutlak_veriler)
# Out:
# Ortalama: 0.7
# standart sapma: 26.487921775783015
# logaritmik veriler: [ 1 55  9 23 13 21 23 37 29  6]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y)
plt.title('sinüs Grafiği')
plt.xlabel('X ekseni')
plt.ylabel('Y ekseni')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

#Yıllara göre satışlar
yillar =[2018,2019,2020,2021,2022]
satislar =[ 140,150,140,150,140]

#satış grafiğini çiz
plt.plot(yillar,satislar,marker='o')
#grafik başlıkları
plt.title("Yıllara göre satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

#grafiği göster
plt.show()

# %%
links = soup.find_all('a')
for link in links:
 href=link.get('href')
text=link.text.strip()
if href:
 print("bağlantı metni:". text , "URL", href)
print("Toplam bulunan bilgi sayısı", len(links), "adet")
else:
print("bağlantı başarısız:",repsonse.status_code)
# Out:
#   File "<ipython-input-30-c49d3a8c7f2c>", line 8
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
import os
import cv2
